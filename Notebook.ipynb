# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import time

from PokerRepository import PokerRepository

repo = PokerRepository()
repo.connect()

print("Deserializing values...")
start_time = time.perf_counter()

results = repo.select_all_results()
df = pd.DataFrame(results)

end_time = time.perf_counter()
print(f"Elapsed: {end_time - start_time:.2f}s")

df
# Out:
# Elapsed: 21.38s
#         hand_value                                      winning_hands  \
# 0          2837760  [[{'rank': Rank.JACK, 'suit': Suit.SPADE}, {'r...
# 1          2649600  [[{'rank': Rank.EIGHT, 'suit': Suit.CLUB}, {'r...
# 2          6627328  [[{'rank': Rank.FIVE, 'suit': Suit.DIAMOND}, {...
# 3          6216068  [[{'rank': Rank.ACE, 'suit': Suit.HEART}, {'ra...
# 4          6983680  [[{'rank': Rank.TEN, 'suit': Suit.DIAMOND}, {'...
# ...            ...                                                ...
# 514995     2770432  [[{'rank': Rank.TEN, 'suit': Suit.CLUB}, {'ran...
# 514996     3586560  [[{'rank': Rank.SIX, 'suit': Suit.CLUB}, {'ran...
# 514997     2702080  [[{'rank': Rank.NINE, 'suit': Suit.CLUB}, {'ra...
# 514998     4049152  [[{'rank': Rank.KING, 'suit': Suit.HEART}, {'r...
# 514999     2706432  [[{'rank': Rank.NINE, 'suit': Suit.SPADE}, {'r...
#
#                                        winning_hole_cards
# 0       [[{'rank': Rank.KING, 'suit': Suit.DIAMOND}, {...
# 1       [[{'rank': Rank.EIGHT, 'suit': Suit.CLUB}, {'r...
# 2       [[{'rank': Rank.FIVE, 'suit': Suit.DIAMOND}, {...
# 3       [[{'rank': Rank.EIGHT, 'suit': Suit.HEART}, {'...
# 4       [[{'rank': Rank.JACK, 'suit': Suit.DIAMOND}, {...
# ...                                                   ...
# 514995  [[{'rank': Rank.TEN, 'suit': Suit.CLUB}, {'ran...
# 514996  [[{'rank': Rank.SIX, 'suit': Suit.CLUB}, {'ran...
# 514997  [[{'rank': Rank.JACK, 'suit': Suit.HEART}, {'r...
# 514998  [[{'rank': Rank.NINE, 'suit': Suit.HEART}, {'r...
# 514999  [[{'rank': Rank.NINE, 'suit': Suit.SPADE}, {'r...
#
# [515000 rows x 3 columns]
